# %%
num = 100
print(num)
print("It's datatype is,", type(num))

fnum = 34.45
print(fnum)
print("It's datatype is,", type(fnum))

cnum = 3 + 4j
print(cnum)
print("It's datatype is,", type(cnum))
# Out:
# 100
# It's datatype is, <class 'int'>
# 34.45
# It's datatype is, <class 'float'>
# (3+4j)
# It's datatype is, <class 'complex'>
