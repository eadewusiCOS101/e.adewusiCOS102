# %%
import pandas as pd

boys = {"Name":  ["Chinedu", "Liam", "Wale", "Gbenga", "Abiola","Kola", "Kunle", "George", "Thomas", "Wesley"],
        "Ages": [19, 16, 18, 17, 20, 19, 16, 18, 17, 19],
        "Heights": [5.7, 5.9, 5.8, 6.1, 5.9, 5.5, 6.1, 5.4, 5.8, 5.7],
        "Scores": [74, 87, 75, 68, 66, 78, 87, 98, 54, 60]}

girls = {"Name": ["Evelyn", "Jessica", "Somto", "Edith", "Liza", "Madonna", "Waje", "Tola", "Aisha", "Latifa"],
         "Ages": [17, 16, 17, 18, 16, 18, 17, 20, 19, 17],
         "Heights": [5.5, 6.0, 5.4, 5.9, 5.6, 5.5, 6.1, 6.0, 5.7, 5.5],
         "Scores": [80, 85, 70, 60, 76, 66, 87, 95, 50, 49]
}

df_boys = pd.DataFrame(boys)
df_girls = pd.DataFrame(girls)

printing_operation = input("Which table would you like to print out?" \
"1) Boys data" \
"2)Girls data")

if printing_operation == "1":
    print(df_boys)
elif printing_operation == "2":
    print(df_girls)
else:
    print ("invalid operation")
# Out:
#       Name  Ages  Heights  Scores
# 0  Chinedu    19      5.7      74
# 1     Liam    16      5.9      87
# 2     Wale    18      5.8      75
# 3   Gbenga    17      6.1      68
# 4   Abiola    20      5.9      66
# 5     Kola    19      5.5      78
# 6    Kunle    16      6.1      87
# 7   George    18      5.4      98
# 8   Thomas    17      5.8      54
# 9   Wesley    19      5.7      60
