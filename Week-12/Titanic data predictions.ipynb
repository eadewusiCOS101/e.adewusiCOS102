# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix

# %%
titanic_data = pd.read_csv("C:/Users/Guest User/Vproject/e.adewusiCOS102/week-4/Project-2/titanic.csv")
titanic_data.drop(columns="Cabin", inplace = True)
titanic_data["Age"] = titanic_data["Age"].fillna(titanic_data["Age"].mean(), inplace = True)
titanic_data["Embarked"] = titanic_data["Embarked"].fillna(titanic_data["Embarked"].mode()[0], inplace = True)
# Out:
# C:\Users\Guest User\AppData\Local\Temp\ipykernel_11740\4114920476.py:3: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   titanic_data["Age"] = titanic_data["Age"].fillna(titanic_data["Age"].mean(), inplace = True)
# ...

# %%
x = titanic_data.drop(columns = ["Survived", "Name", "Ticket", "Sex", "Embarked"])
y = titanic_data["Survived"]

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 42)

# %%
lr = LogisticRegression()
lr.fit(x_train, y_train)
Lr_prediction = lr.predict(x_test)

print(accuracy_score(y_test, Lr_prediction))
print(precision_score(y_test, Lr_prediction))
print(recall_score(y_test, Lr_prediction))
print(confusion_matrix(y_test, Lr_prediction))
# Out:
# 0.7318435754189944
# 0.7708333333333334
# 0.5
# [[94 11]
#  [37 37]]

# %%
dt = DecisionTreeClassifier()
dt.fit(x_train, y_train)
Dt_prediction = dt.predict(x_test)

print(accuracy_score(y_test, Dt_prediction))
print(precision_score(y_test, Dt_prediction))
print(recall_score(y_test, Dt_prediction))
print(confusion_matrix(y_test, Dt_prediction))
# Out:
# 0.664804469273743
# 0.5897435897435898
# 0.6216216216216216
# [[73 32]
#  [28 46]]
