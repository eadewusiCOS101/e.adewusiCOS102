# %%
    


print("Welcome to the interest amount calculator\n")
while True:
    p = float(input("What  is the principal in naira?"))
    r = float(input("What is the interest rate in percentage?"))
    t = float(input("What is the time in years?"))
    print("")

    process = input("Which interest amount would you like to calculate?\n1)Simple Inerest. \n2)Compound Interest. \n3)Annuity. \nPlease use the number code for each operation to run it.\n\nuse Keyword 'Quit' to stop the program.\n")
    if process == "1":
        a = p * (1 + (r * t / 100))
        print(f"\nThe simple interest amount is ₦{a:.2f}")
    elif process == "2":
        a = p * (1 + ((r / 100) ** t))
        print(f"\nThe compound interest amount is ₦{a:.2f}")
    elif process == "3":
        a = p * ((((1 + (r / t)) ** t) - 1) / (r / t))
        print(f"\nThe annuity plan amount is ₦{a:.2f}")
    elif process.lower() == "quit":
        print("\nShutting down the program.")
        break
    else:
        print("\nIncorrect, choose a process using the number code\nor press quit.")
# Out:
# Welcome to the interest amount calculator
# What  is the principal in naira? 70000
# What is the interest rate in percentage? 15
# What is the time in years? 2
# Which interest amount would you like to calculate?
# 1)Simple Inerest.
# 2)Compound Interest.
# 3)Annuity.
# Please use the number code for each operation to run it.
#
# use Keyword 'Quit' to stop the program.
#  1
# The simple interest amount is ₦91000.00
# What  is the principal in naira? beans
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 3
#       1 print("Welcome to the interest amount calculator\n")
#       2 while True:
# ----> 3     p = float(input("What  is the principal in naira?"))
#       4     r = float(input("What is the interest rate in percentage?"))
#       5     t = float(input("What is the time in years?"))
#
# ValueError: could not convert string to float: 'beans'

# %% [markdown]
#
#
#
# print("Welcome to the interest amount calculator\n")
# while True:
#     p = float(input("What  is the principal in naira?"))
#     r = float(input("What is the interest rate in percentage?")) ->Taking inputs from the user.
#     t = float(input("What is the time in years?"))
#     print("")
#
#     process = input("Which interest amount would you like to calculate?\n1)Simple Inerest. \n2)Compound Interest. \n3)Annuity. \nPlease use the number code for each operation to run it.\n\nuse Keyword 'Quit' to stop the program.\n") ->Identifying the process using assigned number codes.
#     if process == "1":
#         a = p * (1 + (r * t / 100))
#         print(f"\nThe simple interest amount is ₦{a:.2f}")
#     elif process == "2":
#         a = p * (1 + ((r / 100) ** t))
#         print(f"\nThe compound interest amount is ₦{a:.2f}")
#     elif process == "3":
#         a = p * ((((1 + (r / t)) ** t) - 1) / (r / t))
#         print(f"\nThe annuity plan amount is ₦{a:.2f}")
#     elif process.lower() == "quit":
#         print("\nShutting down the program.")
#         break
#     else:
#         print("\nIncorrect, choose a process using the number code\nor press quit.")
#
# This program essentially loops forever, taking inputs continuously until the keyword 'quit' is used.
