# %% [markdown]
# Project 1
# a)
# ![image.png](attachment:5b01d67c-d4dd-4f5d-84af-3b4f8876c640.png)
#
# ![Checkout flowchart.png](attachment:5529fbee-9fbd-4feb-83bf-0580b2b3ff23.png)

# %% [markdown]
# b)![Morning routine flowchart.png](attachment:ae07048d-4f4e-46cc-9eb3-695f23defe56.png)

# %% [markdown]
# c)
# ![image.png](attachment:dd7d8d9b-5e41-473c-b6dc-b0f1a7e6ce58.png)
