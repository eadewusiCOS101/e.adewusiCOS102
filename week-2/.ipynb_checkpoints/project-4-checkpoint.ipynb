# %%
def int_input(prompt):
    while True:
        try:
            a = int(input(prompt))
            return a
        except ValueError:
            print("Invalid input.")

print("This is the ATR evaluation script.\n")
while True:

    experience = int_input("How many years of experience do you have in this industrial field?")
    age = int_input("What is your current age?\n")
    if age < 17 or age > 60 or experience > 45:
        print("Invalid entries for evaluation, retry.")
    else:
        if experience > 25 and age >= 55:
            print("Your ATR is ₦5,600,000.00")
        elif experience > 20 and age >= 45:
            print("Your ATR is ₦4,480,000.00")
        elif experience > 10 and age >= 35:
            print("Your ATR is ₦1,500,000.00")
        elif experience < 10 and age < 35:
            print("Your ATR is ₦550,000.00")
        elif (age - experience) < 17:
            print("Invalid inputs for evaluation, retry.")
        else:
            print("Indeterminate ATR. Locate a taxation proffessional within the next 72 hours.")
    print("")

    quit_opt = input("\nWould you like to end the program? Y/N")
    if quit_opt.lower() == "y":
        print("Ending the program.")
        break
# Out:
# This is the ATR evaluation script.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 12
#       9 print("This is the ATR evaluation script.\n")
#      10 while True:
# ---> 12     experience = int_input("How many years of experience do you have in this industrial field?")
#      13     age = int_input("What is your current age?\n")
#      14     if age < 17 or age > 60 or experience > 45:
#
# Cell In[1], line 4, in int_input(prompt)
#       2 while True:
#       3     try:
# ----> 4         a = int(input(prompt))
#       5         return a
#       6     except ValueError:
#
# File ~\anaconda3\Lib\site-packages\ipykernel\kernelbase.py:1275, in Kernel.raw_input(self, prompt)
#    1273     msg = "raw_input was called, but this frontend does not support input requests."
#    1274     raise StdinNotImplementedError(msg)
# -> 1275 return self._input_request(
#    1276     str(prompt),
#    1277     self._parent_ident["shell"],
#    1278     self.get_parent("shell"),
#    1279     password=False,
#    1280 )
#
# File ~\anaconda3\Lib\site-packages\ipykernel\kernelbase.py:1320, in Kernel._input_request(self, prompt, ident, parent, password)
#    1317 except KeyboardInterrupt:
#    1318     # re-raise KeyboardInterrupt, to truncate traceback
#    1319     msg = "Interrupted by user"
# -> 1320     raise KeyboardInterrupt(msg) from None
#    1321 except Exception:
#    1322     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %% [markdown]
# ##### def int_input(prompt):
#     while True:
#         try:
#             a = int(input(prompt))
#             return a
#         except ValueError:
#             print("Invalid input.")
#
# print("This is the ATR evaluation script.\n")
# while True:
#
#     experience = int_input("How many years of experience do you have in this industrial field?")
#     age = int_input("What is your current age?\n")
#     if age < 17 or age > 60 or experience > 45:
#         print("Invalid entries for evaluation, retry.")
#     else:
#         if experience > 25 and age >= 55:
#             print("Your ATR is ₦5,600,000.00")
#         elif experience > 20 and age >= 45:
#             print("Your ATR is ₦4,480,000.00")
#         elif experience > 10 and age >= 35:
#             print("Your ATR is ₦1,500,000.00")
#         elif experience < 10 and age < 35:
#             print("Your ATR is ₦550,000.00")
#         elif (age - experience) < 17:
#             print("Invalid inputs for evaluation, retry.")
#         else:
#             print("Indeterminate ATR. Locate a taxation proffessional within the next 72 hours.")
#     print("")
#
#     quit_opt = input("\nWould you like to end the program? Y/N")
#     if quit_opt.lower() == "y":
#         print("Ending the program.")
#         break

# %%
def int_input(prompt):
    while True:
        try:
            a = int(input(prompt))
            return a
        except ValueError:
            print("Invalid input.")

print("This is the ATR evaluation script.\n")
while True:

    experience = int_input("How many years of experience do you have in this industrial field?")
    age = int_input("What is your current age?\n")
    if age < 17 or age > 60 or experience > 45 or experience >= age:
        print("Invalid entries for evaluation, retry.")
    else:
        if experience > 25 and age >= 55:
            print("Your ATR is ₦5,600,000.00")
        elif experience > 20 and age >= 45:
            print("Your ATR is ₦4,480,000.00")
        elif experience > 10 and age >= 35:
            print("Your ATR is ₦1,500,000.00")
        elif experience < 10 and age < 35:
            print("Your ATR is ₦550,000.00")
        elif (age - experience) < 17:
            print("Invalid inputs for evaluation, retry.")
        else:
            print("Indeterminate ATR. Locate a taxation proffessional within the next 72 hours.")
    print("")

    quit_opt = input("\nWould you like to end the program? Y/N")
    if quit_opt.lower() == "y":
        print("Ending the program.")
        break
# Out:
# This is the ATR evaluation script.
# How many years of experience do you have in this industrial field? hello
# Invalid input.
# How many years of experience do you have in this industrial field? 70
# What is your current age?
#  5
# Invalid entries for evaluation, retry.
# Would you like to end the program? Y/N n
# How many years of experience do you have in this industrial field? 25
# What is your current age?
#  50
# Your ATR is ₦4,480,000.00
